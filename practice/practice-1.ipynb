# %%
from dotenv import load_dotenv
load_dotenv()
import os
from groq import Groq
from langchain_groq import ChatGroq
from IPython.display import Markdown
groq_key = os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
model = ChatGroq(model="llama-3.33-70b-versatile",api_key=groq_key)
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000025D7D778AF0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000025D7D9223F0>, model_name='llama-3.33-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# Out:
# I can be used in a variety of ways, from helping you plan a vacation to creating art. I'm here to assist you in finding the help or information you need. My strengths include answering questions, generating text and images and even just chatting with you.
